# %%
import pandas as pd

# %%
# 读取 Parquet 文件
df = pd.read_parquet('D:\Git\GitLoadWareHouse\Hackathon\data\dataset_with_aug_dict.parquet')

# %%
# 1. 查看所有的“键”（列名/Schema）
print("列名 (Keys):")
print(df.columns.tolist())

# 2. 查看前几行数据 (Values)
print("\n数据预览:")
print(df.head(20))

# 3. 查看数据类型信息
print("\n数据结构信息:")
print(df.info())
# Out:
# 列名 (Keys):
# ...
